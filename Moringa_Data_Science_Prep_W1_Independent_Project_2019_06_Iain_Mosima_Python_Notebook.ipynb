# %%
#prompt the user to enter the values
value1 = float(input("Input the first mass(In pounds): ")) 
value2 = float(input("Input the second mass(In pounds): "))

# calculate the sum of the two values
sum = value1 + value2
print("The sum is:", sum)

# perform average of the two values
average = (sum)/2
print("The average is:", sum)

# quotient if value1 is divided by value2
print("If " +str(value1)+ " pounds is divided by " +str(value2)+ " pounds the quotient is:", value1%value2)

# quotient if value2 is divided by value1
print("If " +str(value2)+ " pounds is divided by " +str(value1)+ " pounds the quotient is:", value2%value1)

# check whether value1 is odd or even
if value1%2 == 0:
    print(value1, "Is an even number.")
else:
    prin(value1, "Is an odd number.")

# check whether value2 is odd or even
if value2%2 == 0:
    print(value2, "Is an even number.")
else:
    print(value290, "Is an odd number.")
# Out:
# Input the first mass(In pounds): 8
# Input the second mass(In pounds): 90
# The sum is: 98.0
# The average is: 98.0
# If 8.0 pounds is divided by 90.0 pounds the quotient is: 8.0
# If 90.0 pounds is divided by 8.0 pounds the quotient is: 2.0
# 8.0 Is an even number.
# 90.0 Is an even number.
